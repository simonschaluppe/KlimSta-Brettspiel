# %%
# %load_ext autoreload
# %autoreload 2
from model.simulate import run_simulation

version = "Versionen/paper_draft_v1"

games, plays = run_simulation(
    version,
    n_games=10_000,
    rule="free_choice",
    log_choices=False
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       3 from model.simulate import run_simulation
#       5 version = "Versionen/paper_draft_v1"
# ----> 7 games, plays = run_simulation(
#       8     version,
#       9     n_games=10_000,
#      10     rule="free_choice",
#      11     log_choices=False
#      12 )
#
# TypeError: run_simulation() got an unexpected keyword argument 'log_choices'
