# %%
import datetime
import pandas as pd
import seaborn as sns
import os

my_folder = "Versionen/aug-14"

df_all = pd.read_parquet(my_folder + "/History.parquet")
cards = pd.read_pickle(my_folder + "/cards.pkl")

datetime.datetime.fromtimestamp(os.path.getmtime(my_folder + "/History.parquet"))
# Out:
# datetime.datetime(2026, 8, 15, 12, 40, 13, 133439)

# %%
df_all.head(2)
# Out:
#    budget  bau_em  runde  game_id  wae_schu  wae_tech  wp_eff  bedarf  \
# 0       6       9      1        0         3         0      -1       4
# 1      -7       9      2        0         4         4       2       4
#
#    strom_prod  speicher  zufriedenheit  sp                     slots  \
# 0           0         2              4  38  [-1, -1, 48, -1, -1, -1]
# 1           0         2              5  58  [21, -1, 48, 58, -1, 73]
#
#                                      occupied                 played_cards  \
# 0                                   [Dämmung]                  [48, 9, 12]
# 1  [Dämmung, Wärmeerzeugung, Fenster, Abgabe]  [9, 73, 12, 48, 20, 21, 58]
#
#   excluded_ids                                   played_cards_log  \
# 0          [8]  [{'runde': 1, 'card_id': 9}, {'runde': 1, 'car...
# 1          [8]  [{'runde': 1, 'card_id': 9}, {'runde': 1, 'car...
#
#      round_end_reason  netzbezug
# 0  No money available          8
# 1  No money available         16

# %%
cards.tail()
# Out:
#                        Name     Slot/Stapel  Count Heizsystem  Kosten  \
# 51            Erdwärmepumpe  Wärmeerzeugung      1         WP       2
# 52      Fernwärme-Anschluss  Wärmeerzeugung      1         FW       1
# 53   Grundwasser-Wärmepumpe  Wärmeerzeugung      1         WP       2
# 54               Grünes Gas  Wärmeerzeugung      1         GG       2
# 55  Zentrale Luftwärmepumpe  Wärmeerzeugung      1         WP       2
#
#     BauEmissionen  SofortCO2  Strombedarf  Stromproduktion  Stromspeicher  \
# 51              0         10            0                0              0
# 52              0          0            0                0              0
# 53              0          0            0                0              0
# 54              0          0            0                0              0
# 55              0          0            0                0              0
#
#     ...  REAL Wärmepumpen-Effizienz  Voraussetzung Spalte  Voraussetzung Wert  \
# 51  ...                         2.0                   NaN                 NaN
# 52  ...                         NaN                   NaN                 NaN
# 53  ...                         2.0                   NaN                 NaN
# 54  ...                         NaN                   NaN                 NaN
# 55  ...                         1.0                   NaN                 NaN
#
#     Voraussetzung Wert NICHT  EffektParsed  \
# 51                       NaN    EFEFXXXXWP
# 52                       NaN          XXFW
# 53                       NaN    EFEFXXXXWP
# 54                       NaN          XXGG
# 55                       NaN      EFXXXXWP
#
#                                          Beschreibung  id  prerequisites  \
# 51  "Eine Erdwärmepumpe nutzt Wärme aus dem Erdrei...  68             []
# 52  "Fernwärme ist einfach und im Allgemeinen umwe...  69             []
# 53  "Eine Grundwasser-Wärmepumpe nutzt die relativ...  70             []
# 54  "Grünes Gas kann bestehende Gasheizungen weite...  71             []
# 55  "Eine zentrale Luftwärmepumpe versorgt das gan...  73             []
#
#     exclusions  ws_prerequisites
# 51          []               0.0
# 52          []               0.0
# 53          []               0.0
# 54          []               0.0
# 55          []               0.0
#
# [5 rows x 31 columns]

# %%
df = df_all[df_all["runde"]==4]
df.head(3)
len(df)
df.columns
# Out:
# Index(['budget', 'bau_em', 'runde', 'game_id', 'wae_schu', 'wae_tech',
#        'wp_eff', 'bedarf', 'strom_prod', 'speicher', 'zufriedenheit', 'sp',
#        'slots', 'occupied', 'played_cards', 'excluded_ids', 'played_cards_log',
#        'round_end_reason', 'netzbezug'],
#       dtype='object')

# %%
df[[ "bau_em", "wae_schu", "bedarf", "speicher", "strom_prod", "zufriedenheit", "budget","sp"]].hist(layout=(1, 8), figsize=(18, 3))
# Out:
# array([[<Axes: title={'center': 'bau_em'}>,
#         <Axes: title={'center': 'wae_schu'}>,
#         <Axes: title={'center': 'bedarf'}>,
#         <Axes: title={'center': 'speicher'}>,
#         <Axes: title={'center': 'strom_prod'}>,
#         <Axes: title={'center': 'zufriedenheit'}>,
#         <Axes: title={'center': 'budget'}>,
#         <Axes: title={'center': 'sp'}>]], dtype=object)

# %%
m = pd.crosstab( df['zufriedenheit'], df['sp'])
sns.heatmap(m,  cmap='inferno', vmax=150)
# Out:
# <Axes: xlabel='sp', ylabel='zufriedenheit'>

# %%
final_games = (
    df
    .loc[df["runde"] == 4]
    #.drop_duplicates(subset="game_id")   
)
#final_games = final_games.drop(final_games[final_games["budget"] < 0].index)
len(final_games)
# Out:
# 4258

# %%
games_with_ws_5 = final_games[final_games["played_cards"].apply(lambda x: 26 in x)]
# 26 ist Wandheizung -> Bed. WS >= 5
games_with_ws_5['wae_schu'].hist()
# Out:
# <Axes: >

# %%
# HIER IST DER CODE VERÄNDERT UM DIE NIEDRIGSTEN SIEGPUNKTE ZU FINDEN
# nsmallest statt nlargest

best_percent = (
    final_games
    .nsmallest(max(1, round(len(final_games) * 0.01)), "sp")
    .copy()
)
best_percent[["game_id", "sp", "budget"]].head(10)
# Out:
#        game_id   sp  budget
# 6887      2576 -104      -1
# 8736      3274  -96       0
# 1484       563  -92      -1
# 1289       492  -90      10
# 652        247  -89       2
# 1559       593  -86      -1
# 14291     5305  -84       3
# 20693     7714  -82      10
# 25363     9496  -81       0
# 15888     5907  -78      -5

# %%
slots = cards["Slot/Stapel"].unique()
single_slots = [slot for slot in slots if not slot.startswith("*")]

id_to_name = cards.set_index("id")["Name"].to_dict()
def map_cards(slot_values):
    return {
        slot_name: id_to_name.get(card_id)
        for slot_name, card_id in zip(single_slots, slot_values)
        if card_id >= 0
    }

name_map = cards["Name"].to_dict()

best_percent["played_cards_named_log"] = best_percent["played_cards_log"].apply(
    lambda cardld: [
        {**card, "card_id": name_map.get(card["card_id"], card["card_id"])}
        for card in cardld
    ]
)

pd.set_option('display.max_colwidth', None)
best_percent["installed_cards"] = best_percent["slots"].apply(map_cards)
best_percent[
    ["game_id", "sp", "budget", "installed_cards", "played_cards_log"]
].head(20)
# Out:
#        game_id   sp  budget  \
# 6887      2576 -104      -1
# 8736      3274  -96       0
# 1484       563  -92      -1
# 1289       492  -90      10
# 652        247  -89       2
# 1559       593  -86      -1
# 14291     5305  -84       3
# 20693     7714  -82      10
# 25363     9496  -81       0
# 15888     5907  -78      -5
# 11260     4187  -77      -2
# 2917      1106  -76      -2
# 11073     4123  -75       3
# 8693      3259  -74      -7
# 23071     8615  -74      -3
# 24495     9165  -71      -4
# 8490      3186  -70       2
# 21151     7892  -69       5
# 77          33  -67       9
# 2953      1120  -66       4
#
#                                                                                                                                                                                                                                                            installed_cards  \
# 6887   {'Abgabe': 'Niedertemperatur Radiator', 'Dachnutzung': 'Mittlere Dach-PV-Anlage', 'Dämmung': 'Standardsanierung ökologisch', 'Fenster': 'Fenstertausch: Passivhaus ökologisch', 'Lüftung': 'Dezentrale Lüftungsgeräte', 'Wärmeerzeugung': 'Grundwasser-Wärmepumpe'}
# 8736                  {'Abgabe': 'Radiatoren mit Lüftern', 'Dachnutzung': 'Mittlere Dach-PV-Anlage', 'Dämmung': 'Passivhaussanierung  ökologisch', 'Fenster': 'Tausch der Verglasung', 'Lüftung': 'Dezentrale Lüftungsgeräte', 'Wärmeerzeugung': 'Grundwasser-Wärmepumpe'}
# 1484                                                                                         {'Dachnutzung': 'Mittlere Dach-PV-Anlage', 'Dämmung': 'Passivhaussanierung  ökologisch', 'Fenster': 'Fenstertausch: Passivhaus', 'Wärmeerzeugung': 'Zentrale Luftwärmepumpe'}
# 1289                                                                                        {'Dachnutzung': 'Grosse Dach-PV-Anlage', 'Dämmung': 'Standardsanierung ökologisch', 'Fenster': 'Fenstertausch: Passivhaus ökologisch', 'Lüftung': 'Dezentrale Lüftungsgeräte'}
# 652                                                  {'Dachnutzung': 'Kleine Dach-PV-Anlage', 'Dämmung': 'Passivhaussanierung  ökologisch', 'Fenster': 'Fenstertausch: Passivhaus', 'Lüftung': 'Dezentrale Lüftungsgeräte', 'Wärmeerzeugung': 'Dezentrale Luftwärmepumpe'}
# 1559                      {'Abgabe': 'Fussbodenheizung', 'Dachnutzung': 'Mittlere Dach-PV-Anlage', 'Dämmung': 'Passivhaussanierung  ökologisch', 'Fenster': 'Fenstertausch: Holz-Alu', 'Lüftung': 'Mechanische Abluftanlagen', 'Wärmeerzeugung': 'Grundwasser-Wärmepumpe'}
# 14291                       {'Abgabe': 'Wandheizung', 'Dachnutzung': 'PV Dachziegel', 'Dämmung': 'Passivhaussanierung  ökologisch', 'Fenster': 'Fenstertausch: Passivhaus ökologisch', 'Lüftung': 'Dezentrale Lüftungsgeräte', 'Wärmeerzeugung': 'Grundwasser-Wärmepumpe'}
# 20693                                                                                                                                      {'Dachnutzung': 'Grosse Dach-PV-Anlage', 'Dämmung': 'Ambitionierte Sanierung ökologisch', 'Fenster': 'Fenstertausch: Holz-Alu'}
# 25363                                                      {'Dachnutzung': 'Thermische Solaranlage', 'Dämmung': 'Passivhaussanierung  ökologisch', 'Fenster': 'Tausch der Verglasung', 'Lüftung': 'Mechanische Abluftanlagen', 'Wärmeerzeugung': 'Grundwasser-Wärmepumpe'}
# 15888                             {'Abgabe': 'Niedertemperatur Radiator', 'Dachnutzung': 'Grosse Dach-PV-Anlage', 'Dämmung': 'Standardsanierung', 'Fenster': 'Tausch der Verglasung', 'Lüftung': 'Mechanische Abluftanlagen', 'Wärmeerzeugung': 'Zentrale Luftwärmepumpe'}
# 11260                                                     {'Abgabe': 'Niedertemperatur Radiator', 'Dachnutzung': 'Kleine Dach-PV-Anlage', 'Dämmung': 'Passivhaussanierung  ökologisch', 'Fenster': 'Fenstertausch: Holz-Alu', 'Wärmeerzeugung': 'Zentrale Luftwärmepumpe'}
# 2917                                                {'Abgabe': 'Deckenheizung', 'Dachnutzung': 'Dachgärten', 'Dämmung': 'Standardsanierung ökologisch', 'Fenster': 'Fenstertausch: Passivhaus', 'Lüftung': 'Mechanische Abluftanlagen', 'Wärmeerzeugung': 'Erdwärmepumpe'}
# 11073                     {'Abgabe': 'Deckenheizung', 'Dachnutzung': 'Grosse Dach-PV-Anlage', 'Dämmung': 'Passivhaussanierung  ökologisch', 'Fenster': 'Fenstertausch: Passivhaus', 'Lüftung': 'Dezentrale Lüftungsgeräte', 'Wärmeerzeugung': 'Dezentrale Luftwärmepumpe'}
# 8693            {'Abgabe': 'Radiatoren mit Lüftern', 'Dachnutzung': 'Kleine Dach-PV-Anlage', 'Dämmung': 'Ambitionierte Sanierung ökologisch', 'Fenster': 'Fenstertausch: Holz-Alu', 'Lüftung': 'Mechanische Abluftanlagen', 'Wärmeerzeugung': 'Dezentrale Luftwärmepumpe'}
# 23071              {'Abgabe': 'Niedertemperatur Radiator', 'Dachnutzung': 'Mittlere Dach-PV-Anlage', 'Dämmung': 'Ambitionierte Sanierung ökologisch', 'Fenster': 'Tausch der Verglasung', 'Lüftung': 'Mechanische Abluftanlagen', 'Wärmeerzeugung': 'Abwasserwärmepumpen'}
# 24495                                                                      {'Dachnutzung': 'Grosse Dach-PV-Anlage', 'Dämmung': 'Standardsanierung', 'Fenster': 'Fenstertausch: Holz-Alu', 'Lüftung': 'Mechanische Abluftanlagen', 'Wärmeerzeugung': 'Abwasserwärmepumpen'}
# 8490                                  {'Dachnutzung': 'PV Dachziegel', 'Dämmung': 'Passivhaussanierung  ökologisch', 'Fenster': 'Fenstertausch: Passivhaus ökologisch', 'Lüftung': 'Lüftungsanlage mit Wärmerückgewinnung', 'Wärmeerzeugung': 'Dezentrale Luftwärmepumpe'}
# 21151                                                                                                           {'Dachnutzung': 'PV Dachziegel', 'Dämmung': 'Standardsanierung ökologisch', 'Fenster': 'Fenstertausch: Holz-Alu', 'Wärmeerzeugung': 'Fernwärme-Anschluss'}
# 77               {'Abgabe': 'Niedertemperatur Radiator', 'Dachnutzung': 'PV Dachziegel', 'Dämmung': 'Passivhaussanierung  ökologisch', 'Fenster': 'Fenstertausch: Passivhaus ökologisch', 'Lüftung': 'Dezentrale Lüftungsgeräte', 'Wärmeerzeugung': 'Fernwärme-Anschluss'}
# 2953                                       {'Abgabe': 'Deckenheizung', 'Dachnutzung': 'Grosse Dach-PV-Anlage', 'Dämmung': 'Passivhaussanierung  ökologisch', 'Fenster': 'Fenstertausch: Holz-Alu', 'Lüftung': 'Mechanische Abluftanlagen', 'Wärmeerzeugung': 'Grünes Gas'}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              played_cards_log
# 6887                                                                                                                                                [{'runde': 1, 'card_id': 30}, {'runde': 1, 'card_id': 5}, {'runde': 1, 'card_id': 14}, {'runde': 2, 'card_id': 56}, {'runde': 3, 'card_id': 15}, {'runde': 3, 'card_id': 59}, {'runde': 3, 'card_id': 1}, {'runde': 3, 'card_id': 48}, {'runde': 4, 'card_id': 70}, {'runde': 4, 'card_id': 23}, {'runde': 4, 'card_id': 16}, {'runde': 4, 'card_id': 0}, {'runde': 4, 'card_id': 18}, {'runde': 4, 'card_id': 10}, {'runde': 4, 'card_id': 20}, {'runde': 4, 'card_id': 8}, {'runde': 4, 'card_id': 13}]
# 8736                                                                                                                                                 [{'runde': 1, 'card_id': 10}, {'runde': 1, 'card_id': 30}, {'runde': 1, 'card_id': 5}, {'runde': 1, 'card_id': 59}, {'runde': 1, 'card_id': 58}, {'runde': 2, 'card_id': 42}, {'runde': 2, 'card_id': 0}, {'runde': 2, 'card_id': 24}, {'runde': 2, 'card_id': 9}, {'runde': 3, 'card_id': 70}, {'runde': 3, 'card_id': 13}, {'runde': 3, 'card_id': 4}, {'runde': 3, 'card_id': 17}, {'runde': 3, 'card_id': 7}, {'runde': 3, 'card_id': 15}, {'runde': 3, 'card_id': 20}, {'runde': 3, 'card_id': 14}]
# 21151                                                                                                                                                                                                                                                                                               [{'runde': 1, 'card_id': 14}, {'runde': 1, 'card_id': 3}, {'runde': 1, 'card_id': 16}, {'runde': 2, 'card_id': 8}, {'runde': 2, 'card_id': 5}, {'runde': 2, 'card_id': 15}, {'runde': 3, 'card_id': 48}, {'runde': 3, 'card_id': 20}, {'runde': 4, 'card_id': 69}, {'runde': 4, 'card_id': 31}, {'runde': 4, 'card_id': 54}, {'runde': 4, 'card_id': 13}]
# 77                                 [{'runde': 1, 'card_id': 42}, {'runde': 2, 'card_id': 56}, {'runde': 2, 'card_id': 8}, {'runde': 2, 'card_id': 10}, {'runde': 2, 'card_id': 20}, {'runde': 2, 'card_id': 5}, {'runde': 2, 'card_id': 14}, {'runde': 3, 'card_id': 0}, {'runde': 3, 'card_id': 59}, {'runde': 3, 'card_id': 15}, {'runde': 3, 'card_id': 69}, {'runde': 3, 'card_id': 23}, {'runde': 3, 'card_id': 18}, {'runde': 3, 'card_id': 2}, {'runde': 3, 'card_id': 7}, {'runde': 3, 'card_id': 3}, {'runde': 3, 'card_id': 31}, {'runde': 4, 'card_id': 1}, {'runde': 4, 'card_id': 16}, {'runde': 4, 'card_id': 13}, {'runde': 4, 'card_id': 12}]
# 2953                                                                                                                                                                                                                                                                                                                                                          [{'runde': 1, 'card_id': 14}, {'runde': 1, 'card_id': 54}, {'runde': 2, 'card_id': 28}, {'runde': 2, 'card_id': 0}, {'runde': 2, 'card_id': 1}, {'runde': 3, 'card_id': 42}, {'runde': 3, 'card_id': 71}, {'runde': 4, 'card_id': 63}, {'runde': 4, 'card_id': 3}, {'runde': 4, 'card_id': 21}]

# %%
from collections import Counter
card_counts = Counter(
    card_name
    for cards in best_percent["installed_cards"]
    for card_name in cards.values()
)

card_frequency = (
    pd.DataFrame(
        card_counts.items(),
        columns=["Karte", "Anzahl_in_Top_1Prozent"]
    )
    .sort_values("Anzahl_in_Top_1Prozent", ascending=False)
    .reset_index(drop=True)
)

card_frequency["Anteil_Top_100"] = (
    card_frequency["Anzahl_in_Top_1Prozent"] / len(best_percent)
)

card_frequency.head(20)
# Out:
#                                    Karte  Anzahl_in_Top_1Prozent  \
# 0              Mechanische Abluftanlagen                      19
# 1        Passivhaussanierung  ökologisch                      18
# 2              Dezentrale Lüftungsgeräte                      15
# 3     Ambitionierte Sanierung ökologisch                      11
# 4                  Tausch der Verglasung                      11
# 5              Niedertemperatur Radiator                      10
# 6                Fenstertausch: Holz-Alu                      10
# 7   Fenstertausch: Passivhaus ökologisch                       9
# 8                  Kleine Dach-PV-Anlage                       9
# 9                  Grosse Dach-PV-Anlage                       8
# 10                   Abwasserwärmepumpen                       8
# 11                         PV Dachziegel                       8
# 12                Radiatoren mit Lüftern                       8
# 13                         Deckenheizung                       7
# 14             Fenstertausch: Passivhaus                       7
# 15               Mittlere Dach-PV-Anlage                       7
# 16                Grundwasser-Wärmepumpe                       7
# 17               Zentrale Luftwärmepumpe                       6
# 18          Standardsanierung ökologisch                       6
# 19                            Dachgärten                       5
#
#     Anteil_Top_100
# 0         0.441860
# 1         0.418605
# 2         0.348837
# 3         0.255814
# 4         0.255814
# 5         0.232558
# 6         0.232558
# 7         0.209302
# 8         0.209302
# 9         0.186047
# 10        0.186047
# 11        0.186047
# 12        0.186047
# 13        0.162791
# 14        0.162791
# 15        0.162791
# 16        0.162791
# 17        0.139535
# 18        0.139535
# 19        0.116279

# %%
id_to_name = cards.set_index("id")["Name"].to_dict()

def extract_installed_cards(played_cards_log):
    return [
        id_to_name.get(entry["card_id"], f"Unknown card ID {entry['card_id']}")
        for entry in played_cards_log
    ]

best_percent["all_installed_cards"] = (
    best_percent["played_cards_log"].apply(extract_installed_cards)
)

best_percent[
    ["game_id", "sp", "all_installed_cards"]
].head(20)
# Out:
#        game_id   sp  \
# 6887      2576 -104
# 8736      3274  -96
# 1484       563  -92
# 1289       492  -90
# 652        247  -89
# 1559       593  -86
# 14291     5305  -84
# 20693     7714  -82
# 25363     9496  -81
# 15888     5907  -78
# 11260     4187  -77
# 2917      1106  -76
# 11073     4123  -75
# 8693      3259  -74
# 23071     8615  -74
# 24495     9165  -71
# 8490      3186  -70
# 21151     7892  -69
# 77          33  -67
# 2953      1120  -66
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             all_installed_cards
# 6887                                                                                                  [Mittlere Dach-PV-Anlage, Bi-Direktionelles Laden, Hausweiter E-Car Port, Fenstertausch: Passivhaus ökologisch, Private Wallboxen, Dezentrale Lüftungsgeräte, E-Herd, Standardsanierung ökologisch, Grundwasser-Wärmepumpe, Niedertemperatur Radiator, Car Sharing, Balkonkraftwerk, Intensive Dachbegrünung, Flexibles Speichermanagement, Außenliegender Sonnenschutz, Grosser Batteriespeicher, Barrierefreier Zugang]
# 8736                                                                                [Flexibles Speichermanagement, Mittlere Dach-PV-Anlage, Bi-Direktionelles Laden, Dezentrale Lüftungsgeräte, Tausch der Verglasung, Passivhaussanierung  ökologisch, Balkonkraftwerk, Radiatoren mit Lüftern, Kleiner Heimspeicher, Grundwasser-Wärmepumpe, Barrierefreier Zugang, Wärmerückgewinnung des Duschwassers, Fassadenbegrünung , Flexibles Lastmanagement, Private Wallboxen, Außenliegender Sonnenschutz, Hausweiter E-Car Port]
# 1484                                                                                                                                                                                                                                                        [Bi-Direktionelles Laden, Flexibles Lastmanagement, Private Wallboxen, Fassadenbegrünung , Car Sharing, Barrierefreier Zugang, Mittlere Dach-PV-Anlage, Hausweiter E-Car Port, Fenstertausch: Passivhaus, Zentrale Luftwärmepumpe, Passivhaussanierung  ökologisch]
# 1289                                                                                                                                                                                         [Hausweiter E-Car Port, Intensive Dachbegrünung, Grosse Dach-PV-Anlage, Außenliegender Sonnenschutz, Fenstertausch: Passivhaus ökologisch, Kleiner Heimspeicher, Balkonkraftwerk, Flexibles Lastmanagement, Standardsanierung ökologisch, Dezentrale Lüftungsgeräte, Bi-Direktionelles Laden, Car Sharing, Fassadenintegrierte PV]
# 652                                                                                                                                                         [Flexibles Speichermanagement, Hausweiter E-Car Port, Kleine Dach-PV-Anlage, Dezentrale Lüftungsgeräte, Passivhaussanierung  ökologisch, Car Sharing, Fassadenintegrierte PV, Barrierefreier Zugang, Fenstertausch: Passivhaus, Kleiner Heimspeicher, Lift-Einbau, Dezentrale Luftwärmepumpe, Thermische Flexibilität, Effiziente Haushaltsgeräte, LED Beleuchtung]
# 1559                                                                                    [Barrierefreier Zugang, Außenliegender Sonnenschutz, Hausweiter E-Car Port, Balkon-Einbau, Mittlere Dach-PV-Anlage, Mechanische Abluftanlagen, Passivhaussanierung  ökologisch, Intensive Dachbegrünung, Grundwasser-Wärmepumpe, Thermische Flexibilität, Flexibles Lastmanagement, Fenstertausch: Holz-Alu, Bi-Direktionelles Laden, Fussbodenheizung, Fassadenbegrünung , Flexibles Speichermanagement, E-Herd, Kleiner Heimspeicher]
# 14291  [Hausweiter E-Car Port, Dezentrale Lüftungsgeräte, E-Herd, Passivhaussanierung  ökologisch, PV Dachziegel, Intensive Dachbegrünung, Fassadenbegrünung , Fenstertausch: Passivhaus ökologisch, Grosser Batteriespeicher, Balkonkraftwerk, Grundwasser-Wärmepumpe, Wandheizung, Bi-Direktionelles Laden, Flexibles Lastmanagement, Effiziente Haushaltsgeräte, Balkon-Einbau, Private Wallboxen, LED Beleuchtung, Wärmerückgewinnung des Duschwassers, Thermische Flexibilität, Flexibles Speichermanagement, Car Sharing]
# 20693                                                                                                                                                                                                                                               [Fenstertausch: Holz-Alu, Flexibles Lastmanagement, Balkonkraftwerk, Hausweiter E-Car Port, Grosse Dach-PV-Anlage, Flexibles Speichermanagement, Fassadenintegrierte PV, Intensive Dachbegrünung, Ambitionierte Sanierung ökologisch, Barrierefreier Zugang, Balkon-Einbau]
# 25363                                                                                                                                                                        [Thermische Solaranlage, Mechanische Abluftanlagen, Flexibles Speichermanagement, Flexibles Lastmanagement, Balkonkraftwerk, Tausch der Verglasung, Hausweiter E-Car Port, Fassadenbegrünung , Außenliegender Sonnenschutz, Passivhaussanierung  ökologisch, Grundwasser-Wärmepumpe, Thermische Flexibilität, Wärmerückgewinnung des Duschwassers]
# 15888                                                                                                                                                                                                        [E-Herd, Hausweiter E-Car Port, Barrierefreier Zugang, Grosse Dach-PV-Anlage, Mechanische Abluftanlagen, Tausch der Verglasung, Fassadenintegrierte PV, Zentrale Luftwärmepumpe, Standardsanierung, Effiziente Haushaltsgeräte, Niedertemperatur Radiator, Balkonkraftwerk, Kleiner Heimspeicher, LED Beleuchtung]
# 11260                                                                                                                                                                       [Lift-Einbau, Car Sharing, Außenliegender Sonnenschutz, Kleine Dach-PV-Anlage, Bi-Direktionelles Laden, Private Wallboxen, Hausweiter E-Car Port, Passivhaussanierung  ökologisch, Zentrale Luftwärmepumpe, Balkon-Einbau, LED Beleuchtung, Flexibles Lastmanagement, Grosser Batteriespeicher, Niedertemperatur Radiator, Fenstertausch: Holz-Alu]
# 2917                                                  [Bi-Direktionelles Laden, Fassadenintegrierte PV, Flexibles Speichermanagement, Mechanische Abluftanlagen, Hausweiter E-Car Port, Fenstertausch: Passivhaus, Private Wallboxen, Dachgärten, Standardsanierung ökologisch, Grosser Batteriespeicher, Erdwärmepumpe, Außenliegender Sonnenschutz, Deckenheizung, LED Beleuchtung, Thermische Flexibilität, Intensive Dachbegrünung, Barrierefreier Zugang, Effiziente Haushaltsgeräte, Wärmerückgewinnung des Duschwassers]
# 11073                                                                                                                              [Grosse Dach-PV-Anlage, Balkonkraftwerk, Außenliegender Sonnenschutz, Flexibles Lastmanagement, Hausweiter E-Car Port, Balkon-Einbau, Passivhaussanierung  ökologisch, Car Sharing, Dezentrale Luftwärmepumpe, Wärmerückgewinnung des Duschwassers, Barrierefreier Zugang, Dezentrale Lüftungsgeräte, Deckenheizung, Fenstertausch: Passivhaus, Effiziente Haushaltsgeräte, LED Beleuchtung]
# 8693                                                                                                                                        [Intensive Dachbegrünung, Barrierefreier Zugang, Car Sharing, Mechanische Abluftanlagen, Hausweiter E-Car Port, Bi-Direktionelles Laden, Ambitionierte Sanierung ökologisch, Radiatoren mit Lüftern, Flexibles Lastmanagement, Kleine Dach-PV-Anlage, Balkon-Einbau, Fenstertausch: Holz-Alu, Dezentrale Luftwärmepumpe, E-Herd, Thermische Flexibilität, Grosser Batteriespeicher]
# 23071                                                                                                                                                                        [Flexibles Lastmanagement, Tausch der Verglasung, Balkonkraftwerk, Hausweiter E-Car Port, Barrierefreier Zugang, Mittlere Dach-PV-Anlage, Grosser Batteriespeicher, Mechanische Abluftanlagen, Ambitionierte Sanierung ökologisch, Niedertemperatur Radiator, Balkon-Einbau, Abwasserwärmepumpen, LED Beleuchtung, E-Herd, Fassadenintegrierte PV]
# 24495                                                                                                                                                  [Private Wallboxen, Grosse Dach-PV-Anlage, Mechanische Abluftanlagen, Car Sharing, Bi-Direktionelles Laden, Balkon-Einbau, Außenliegender Sonnenschutz, Standardsanierung, Intensive Dachbegrünung, Hausweiter E-Car Port, Abwasserwärmepumpen, Fassadenbegrünung , Kleiner Heimspeicher, Balkonkraftwerk, Fenstertausch: Holz-Alu, Wärmerückgewinnung des Duschwassers]
# 8490                                                                                                                                                                                             [Car Sharing, Bi-Direktionelles Laden, Lüftungsanlage mit Wärmerückgewinnung, Hausweiter E-Car Port, Flexibles Lastmanagement, Flexibles Speichermanagement, Fenstertausch: Passivhaus ökologisch, Passivhaussanierung  ökologisch, PV Dachziegel, Barrierefreier Zugang, Dezentrale Luftwärmepumpe, Grosser Batteriespeicher]
# 21151                                                                                                                                                                                                                                                [Hausweiter E-Car Port, LED Beleuchtung, Car Sharing, Grosser Batteriespeicher, Bi-Direktionelles Laden, Private Wallboxen, Standardsanierung ökologisch, Außenliegender Sonnenschutz, Fernwärme-Anschluss, PV Dachziegel, Fenstertausch: Holz-Alu, Barrierefreier Zugang]
# 77                            [Passivhaussanierung  ökologisch, Fenstertausch: Passivhaus ökologisch, Grosser Batteriespeicher, Flexibles Speichermanagement, Außenliegender Sonnenschutz, Bi-Direktionelles Laden, Hausweiter E-Car Port, Balkonkraftwerk, Dezentrale Lüftungsgeräte, Private Wallboxen, Fernwärme-Anschluss, Niedertemperatur Radiator, Intensive Dachbegrünung, Fassadenintegrierte PV, Flexibles Lastmanagement, LED Beleuchtung, PV Dachziegel, E-Herd, Car Sharing, Barrierefreier Zugang, Balkon-Einbau]
# 2953                                                                                                                                                                                                                                                                                                                   [Hausweiter E-Car Port, Fenstertausch: Holz-Alu, Grosse Dach-PV-Anlage, Balkonkraftwerk, E-Herd, Passivhaussanierung  ökologisch, Grünes Gas, Mechanische Abluftanlagen, LED Beleuchtung, Deckenheizung]

# %% [markdown]
# # Häufigkeit aller installierten Karten

# %%
all_card_counts = Counter(
    card
    for cards in best_percent["all_installed_cards"]
    for card in cards
)

top_cards = (
    pd.DataFrame(
        all_card_counts.items(),
        columns=["Karte", "Anzahl"]
    )
    .sort_values("Anzahl", ascending=False)
    .reset_index(drop=True)
)

top_cards.head(20)
# Out:
#                               Karte  Anzahl
# 0             Hausweiter E-Car Port      42
# 1             Barrierefreier Zugang      30
# 2          Flexibles Lastmanagement      28
# 3      Flexibles Speichermanagement      27
# 4           Bi-Direktionelles Laden      27
# 5                       Car Sharing      27
# 6                   Balkonkraftwerk      26
# 7       Außenliegender Sonnenschutz      25
# 8                   LED Beleuchtung      25
# 9           Intensive Dachbegrünung      24
# 10                           E-Herd      21
# 11                    Balkon-Einbau      20
# 12             Kleiner Heimspeicher      20
# 13        Mechanische Abluftanlagen      19
# 14  Passivhaussanierung  ökologisch      18
# 15                Private Wallboxen      18
# 16        Dezentrale Lüftungsgeräte      15
# 17       Effiziente Haushaltsgeräte      13
# 18               Fassadenbegrünung       13
# 19         Grosser Batteriespeicher      13

# %%
# Slot information hinzufügen
import matplotlib.pyplot as plt
from card_colors import slot_colors, default_color
plot_data = (
    top_cards
    .merge(
        cards[["Name", "Slot/Stapel"]],
        left_on="Karte",
        right_on="Name",
        how="left",
    )
    .drop(columns="Name")
    .sort_values("Anzahl")
)

bar_colors = (
    plot_data["Slot/Stapel"]
    .map(slot_colors)
    .fillna(default_color)
)

ax = plot_data.plot.barh(
    x="Karte",
    y="Anzahl",
    color=bar_colors,
    legend=False,
    figsize=(8, 12),
    title="Häufigste Karten in den Top 1% Spielen mit den meisten SP",
)

ax.set_xlabel("Anzahl in den Top-1%-Spielen")
ax.set_ylabel("Karte")

plt.tight_layout()
plt.show()

# %%
best_percent.hist("budget")
df.hist("budget")
# Out:
# array([[<Axes: title={'center': 'budget'}>]], dtype=object)
