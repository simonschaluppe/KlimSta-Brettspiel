# %%
import datetime
import pandas as pd
import seaborn as sns
import os

my_folder = "Versionen/final_final"

df_all = pd.read_parquet(my_folder + "/History.parquet")
cards = pd.read_pickle(my_folder + "/cards.pkl")

datetime.datetime.fromtimestamp(os.path.getmtime(my_folder + "/History.parquet"))
# Out:
# datetime.datetime(2026, 8, 15, 10, 11, 35, 719346)

# %%
df_all.head(2)
# Out:
#    budget  bau_em  runde  game_id  wae_schu  wae_tech  wp_eff  bedarf  \
# 0       4       8      1        0         1         0      -1       3
# 1       3       4      2        0         4         2      -1       8
#
#    strom_prod  speicher  zufriedenheit  sp                     slots  \
# 0           0         0              4  14  [-1, 24, -1, 55, -1, -1]
# 1           0         6              5  54  [-1, 24, 44, 55, -1, 66]
#
#                                           occupied  \
# 0                           [Dachnutzung, Fenster]
# 1  [Wärmeerzeugung, Dämmung, Dachnutzung, Fenster]
#
#                  played_cards excluded_ids  \
# 0                 [24, 3, 55]           []
# 1  [1, 66, 3, 44, 13, 55, 24]           []
#
#                                     played_cards_log    round_end_reason  \
# 0  [{'runde': 1, 'card_id': 3}, {'runde': 1, 'car...  No money available
# 1  [{'runde': 1, 'card_id': 3}, {'runde': 1, 'car...  No money available
#
#    netzbezug
# 0          7
# 1         12

# %%
cards.tail()
# Out:
#                        Name     Slot/Stapel  Count Heizsystem  Kosten  \
# 48            Erdwärmepumpe  Wärmeerzeugung      1         WP       2
# 49      Fernwärme-Anschluss  Wärmeerzeugung      1         FW       1
# 50   Grundwasser-Wärmepumpe  Wärmeerzeugung      1         WP       2
# 51               Grünes Gas  Wärmeerzeugung      1         GG       2
# 52  Zentrale Luftwärmepumpe  Wärmeerzeugung      1         WP       2
#
#     BauEmissionen  SofortCO2  Strombedarf  Stromproduktion  Stromspeicher  \
# 48              0         10            0                0              0
# 49              0          0            0                0              0
# 50              0          0            0                0              0
# 51              0          0            0                0              0
# 52              0          0            0                0              0
#
#     ...  REAL Wärmeschutz  REAL Wärmepumpen-Effizienz  Voraussetzung Spalte  \
# 48  ...               NaN                         2.0                   NaN
# 49  ...               NaN                         NaN                   NaN
# 50  ...               NaN                         2.0                   NaN
# 51  ...               NaN                         NaN                   NaN
# 52  ...               NaN                         1.0                   NaN
#
#     Voraussetzung Wert  Voraussetzung Wert NICHT  EffektParsed  \
# 48                 NaN                       NaN    EFEFXXXXWP
# 49                 NaN                       NaN          XXFW
# 50                 NaN                       NaN    EFEFXXXXWP
# 51                 NaN                       NaN          XXGG
# 52                 NaN                       NaN      EFXXXXWP
#
#                                          Beschreibung  id  prerequisites  \
# 48  "Eine Erdwärmepumpe nutzt Wärme aus dem Erdrei...  65             []
# 49  "Fernwärme ist einfach und im Allgemeinen umwe...  66             []
# 50  "Eine Grundwasser-Wärmepumpe nutzt die relativ...  67             []
# 51  "Grünes Gas kann bestehende Gasheizungen weite...  68             []
# 52  "Eine zentrale Luftwärmepumpe versorgt das gan...  70             []
#
#     exclusions
# 48          []
# 49          []
# 50          []
# 51          []
# 52          []
#
# [5 rows x 30 columns]

# %%
df = df_all[df_all["runde"]==4]
df.head(3)
len(df)
df.columns
# Out:
# Index(['budget', 'bau_em', 'runde', 'game_id', 'wae_schu', 'wae_tech',
#        'wp_eff', 'bedarf', 'strom_prod', 'speicher', 'zufriedenheit', 'sp',
#        'slots', 'occupied', 'played_cards', 'excluded_ids', 'played_cards_log',
#        'round_end_reason', 'netzbezug'],
#       dtype='object')

# %%
df[[ "bau_em", "wae_schu", "bedarf", "speicher", "strom_prod", "zufriedenheit", "budget","sp"]].hist(layout=(1, 8), figsize=(18, 3))
# Out:
# array([[<Axes: title={'center': 'bau_em'}>,
#         <Axes: title={'center': 'wae_schu'}>,
#         <Axes: title={'center': 'bedarf'}>,
#         <Axes: title={'center': 'speicher'}>,
#         <Axes: title={'center': 'strom_prod'}>,
#         <Axes: title={'center': 'zufriedenheit'}>,
#         <Axes: title={'center': 'budget'}>,
#         <Axes: title={'center': 'sp'}>]], dtype=object)

# %%
m = pd.crosstab( df['zufriedenheit'], df['sp'])
sns.heatmap(m,  cmap='inferno', vmax=50)
# Out:
# <Axes: xlabel='sp', ylabel='zufriedenheit'>

# %%
final_games = (
    df
    .loc[df["runde"] == 4]
    #.drop_duplicates(subset="game_id")   
)
#final_games = final_games.drop(final_games[final_games["budget"] < 0].index)
len(final_games)
# Out:
# 43079

# %%
# HIER IST DER CODE VERÄNDERT UM DIE NIEDRIGSTEN SIEGPUNKTE ZU FINDEN
# nsmallest statt nlargest

best_percent = (
    final_games
    .nsmallest(max(1, round(len(final_games) * 0.01)), "sp")
    .copy()
)
best_percent[["game_id", "sp", "budget"]].head(10)
# Out:
#         game_id  sp  budget
# 172548    64306 -70       1
# 203747    75960 -68       0
# 111535    41639 -58       4
# 264564    98558 -58      -2
# 169934    63319 -57       9
# 246446    91871 -57      -2
# 8029       2971 -56     -12
# 147085    54803 -56      -8
# 244256    91038 -56       2
# 61814     23074 -55      -4

# %%
slots = cards["Slot/Stapel"].unique()
single_slots = [slot for slot in slots if not slot.startswith("*")]

id_to_name = cards.set_index("id")["Name"].to_dict()
def map_cards(slot_values):
    return {
        slot_name: id_to_name.get(card_id)
        for slot_name, card_id in zip(single_slots, slot_values)
        if card_id >= 0
    }

name_map = cards["Name"].to_dict()

best_percent["played_cards_named_log"] = best_percent["played_cards_log"].apply(
    lambda cardld: [
        {**card, "card_id": name_map.get(card["card_id"], card["card_id"])}
        for card in cardld
    ]
)

pd.set_option('display.max_colwidth', None)
best_percent["installed_cards"] = best_percent["slots"].apply(map_cards)
best_percent[
    ["game_id", "sp", "budget", "installed_cards", "played_cards_log"]
].head(20)
# Out:
#         game_id  sp  budget  \
# 172548    64306 -70       1
# 203747    75960 -68       0
# 111535    41639 -58       4
# 264564    98558 -58      -2
# 169934    63319 -57       9
# 246446    91871 -57      -2
# 8029       2971 -56     -12
# 147085    54803 -56      -8
# 244256    91038 -56       2
# 61814     23074 -55      -4
# 153637    57240 -55      -6
# 184409    68701 -55      -2
# 92019     34366 -52       6
# 131299    48961 -52       0
# 50700     18907 -51       3
# 136151    50788 -51     -10
# 7130       2640 -50       1
# 31642     11738 -50      -9
# 39739     14769 -50       9
# 177921    66289 -50       7
#
#                                                                                                                                                                                                                                                  installed_cards  \
# 172548  {'Abgabe': 'Fussbodenheizung', 'Dachnutzung': 'Grosse Dach-PV-Anlage', 'Dämmung': 'Passivhaussanierung  ökologisch', 'Fenster': 'Fenstertausch: Passivhaus ökologisch', 'Lüftung': 'Mechanische Abluftanlagen', 'Wärmeerzeugung': 'Abwasserwärmepumpen'}
# 203747      {'Abgabe': 'Radiatoren mit Lüftern', 'Dachnutzung': 'Grosse Dach-PV-Anlage', 'Dämmung': 'Passivhaussanierung  ökologisch', 'Fenster': 'Fenstertausch: Holz-Alu', 'Lüftung': 'Dezentrale Lüftungsgeräte', 'Wärmeerzeugung': 'Grundwasser-Wärmepumpe'}
# 111535                                                                                                                                                                                                                               {'Abgabe': 'Deckenheizung'}
# 264564   {'Abgabe': 'Radiatoren mit Lüftern', 'Dachnutzung': 'Mittlere Dach-PV-Anlage', 'Dämmung': 'Ambitionierte Sanierung ökologisch', 'Fenster': 'Tausch der Verglasung', 'Lüftung': 'Mechanische Abluftanlagen', 'Wärmeerzeugung': 'Grundwasser-Wärmepumpe'}
# 169934                                                             {'Abgabe': 'Radiatoren mit Lüftern', 'Dachnutzung': 'Dachgärten', 'Dämmung': 'Passivhaussanierung  ökologisch', 'Fenster': 'Fenstertausch: Holz-Alu', 'Lüftung': 'Mechanische Abluftanlagen'}
# 246446                {'Abgabe': 'Niedertemperatur Radiator', 'Dachnutzung': 'Dachgärten', 'Dämmung': 'Passivhaussanierung  ökologisch', 'Fenster': 'Tausch der Verglasung', 'Lüftung': 'Mechanische Abluftanlagen', 'Wärmeerzeugung': 'Grundwasser-Wärmepumpe'}
# 8029                                                                                                                   {'Abgabe': 'Deckenheizung', 'Dachnutzung': 'Dachgärten', 'Lüftung': 'Dezentrale Lüftungsgeräte', 'Wärmeerzeugung': 'Abwasserwärmepumpen'}
# 147085                                                                                     {'Dachnutzung': 'PV-Pergola', 'Fenster': 'Fenstertausch: Passivhaus ökologisch', 'Lüftung': 'Mechanische Abluftanlagen', 'Wärmeerzeugung': 'Zentrale Luftwärmepumpe'}
# 244256                   {'Abgabe': 'Niedertemperatur Radiator', 'Dachnutzung': 'PV-Pergola', 'Dämmung': 'Passivhaussanierung  ökologisch', 'Fenster': 'Tausch der Verglasung', 'Lüftung': 'Dezentrale Lüftungsgeräte', 'Wärmeerzeugung': 'Abwasserwärmepumpen'}
# 61814                         {'Abgabe': 'Wandheizung', 'Dachnutzung': 'Dachgärten', 'Dämmung': 'Ambitionierte Sanierung ökologisch', 'Fenster': 'Tausch der Verglasung', 'Lüftung': 'Mechanische Abluftanlagen', 'Wärmeerzeugung': 'Dezentrale Luftwärmepumpe'}
# 153637                                                {'Abgabe': 'Deckenheizung', 'Dachnutzung': 'Mittlere Dach-PV-Anlage', 'Dämmung': 'Ambitionierte Sanierung ökologisch', 'Lüftung': 'Mechanische Abluftanlagen', 'Wärmeerzeugung': 'Grundwasser-Wärmepumpe'}
# 184409        {'Abgabe': 'Radiatoren mit Lüftern', 'Dachnutzung': 'Kleine Dach-PV-Anlage', 'Dämmung': 'Passivhaussanierung  ökologisch', 'Fenster': 'Tausch der Verglasung', 'Lüftung': 'Mechanische Abluftanlagen', 'Wärmeerzeugung': 'Grundwasser-Wärmepumpe'}
# 92019                                                                                                                                                          {'Abgabe': 'Wandheizung', 'Dachnutzung': 'PV Dachziegel', 'Lüftung': 'Mechanische Abluftanlagen'}
# 131299       {'Abgabe': 'Fussbodenheizung', 'Dachnutzung': 'Dachgärten', 'Dämmung': 'Ambitionierte Sanierung ökologisch', 'Fenster': 'Fenstertausch: Passivhaus ökologisch', 'Lüftung': 'Mechanische Abluftanlagen', 'Wärmeerzeugung': 'Grundwasser-Wärmepumpe'}
# 50700                              {'Abgabe': 'Fussbodenheizung', 'Dachnutzung': 'PV Dachziegel', 'Dämmung': 'Passivhaussanierung  ökologisch', 'Fenster': 'Fenstertausch: Holz-Alu', 'Lüftung': 'Dezentrale Lüftungsgeräte', 'Wärmeerzeugung': 'Erdwärmepumpe'}
# 136151                                                                 {'Abgabe': 'Wandheizung', 'Dachnutzung': 'Grosse Dach-PV-Anlage', 'Fenster': 'Tausch der Verglasung', 'Lüftung': 'Mechanische Abluftanlagen', 'Wärmeerzeugung': 'Grundwasser-Wärmepumpe'}
# 7130                                             {'Abgabe': 'Wandheizung', 'Dachnutzung': 'Grosse Dach-PV-Anlage', 'Dämmung': 'Passivhaussanierung  ökologisch', 'Lüftung': 'Lüftungsanlage mit Wärmerückgewinnung', 'Wärmeerzeugung': 'Grundwasser-Wärmepumpe'}
# 31642                                                   {'Abgabe': 'Radiatoren mit Lüftern', 'Dachnutzung': 'Thermische Solaranlage', 'Fenster': 'Tausch der Verglasung', 'Lüftung': 'Dezentrale Lüftungsgeräte', 'Wärmeerzeugung': 'Dezentrale Luftwärmepumpe'}
# 39739                                                                      {'Abgabe': 'Fussbodenheizung', 'Dachnutzung': 'Dachgärten', 'Dämmung': 'Passivhaussanierung  ökologisch', 'Fenster': 'Tausch der Verglasung', 'Lüftung': 'Dezentrale Lüftungsgeräte'}
# 177921                                                                                                                                 {'Abgabe': 'Niedertemperatur Radiator', 'Dachnutzung': 'Mittlere Dach-PV-Anlage', 'Lüftung': 'Mechanische Abluftanlagen'}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             played_cards_log
# 172548                                                                                                                                                                                                           [{'runde': 1, 'card_id': 25}, {'runde': 1, 'card_id': 1}, {'runde': 2, 'card_id': 60}, {'runde': 2, 'card_id': 0}, {'runde': 2, 'card_id': 12}, {'runde': 2, 'card_id': 7}, {'runde': 2, 'card_id': 3}, {'runde': 3, 'card_id': 39}, {'runde': 4, 'card_id': 19}, {'runde': 4, 'card_id': 53}, {'runde': 4, 'card_id': 62}]
# 203747                                                                                                                                                                            [{'runde': 1, 'card_id': 25}, {'runde': 1, 'card_id': 1}, {'runde': 2, 'card_id': 51}, {'runde': 2, 'card_id': 13}, {'runde': 3, 'card_id': 12}, {'runde': 3, 'card_id': 14}, {'runde': 3, 'card_id': 21}, {'runde': 3, 'card_id': 56}, {'runde': 4, 'card_id': 39}, {'runde': 4, 'card_id': 67}, {'runde': 4, 'card_id': 10}, {'runde': 4, 'card_id': 9}]
# 111535                                                                                                                                                                                                                                                                                                                               [{'runde': 1, 'card_id': 7}, {'runde': 1, 'card_id': 2}, {'runde': 1, 'card_id': 1}, {'runde': 2, 'card_id': 8}, {'runde': 3, 'card_id': 15}, {'runde': 4, 'card_id': 18}, {'runde': 4, 'card_id': 11}]
# 264564                                                                                                                    [{'runde': 1, 'card_id': 0}, {'runde': 1, 'card_id': 27}, {'runde': 1, 'card_id': 1}, {'runde': 1, 'card_id': 13}, {'runde': 2, 'card_id': 2}, {'runde': 3, 'card_id': 60}, {'runde': 3, 'card_id': 32}, {'runde': 4, 'card_id': 11}, {'runde': 4, 'card_id': 67}, {'runde': 4, 'card_id': 15}, {'runde': 4, 'card_id': 21}, {'runde': 4, 'card_id': 55}, {'runde': 4, 'card_id': 9}, {'runde': 4, 'card_id': 12}]
# 169934                                                                                                                                                                                                                                                                                                 [{'runde': 1, 'card_id': 21}, {'runde': 1, 'card_id': 51}, {'runde': 1, 'card_id': 1}, {'runde': 2, 'card_id': 7}, {'runde': 2, 'card_id': 60}, {'runde': 2, 'card_id': 24}, {'runde': 3, 'card_id': 2}, {'runde': 4, 'card_id': 39}]
# 246446  [{'runde': 1, 'card_id': 20}, {'runde': 1, 'card_id': 24}, {'runde': 1, 'card_id': 9}, {'runde': 1, 'card_id': 1}, {'runde': 2, 'card_id':
, {'runde': 1, 'card_id': 1}, {'runde': 2, 'card_id': 56}, {'runde': 2, 'card_id': 55}, {'runde': 3, 'card_id': 24}, {'runde': 3, 'card_id': 8}, {'runde': 4, 'card_id': 39}]
# 177921                                                                                                                                                                               [{'runde': 1, 'card_id': 2}, {'runde': 1, 'card_id': 20}, {'runde': 1, 'card_id': 1}, {'runde': 2, 'card_id': 17}, {'runde': 2, 'card_id': 27}, {'runde': 3, 'card_id': 11}, {'runde': 3, 'card_id': 15}, {'runde': 4, 'card_id': 60}, {'runde': 4, 'card_id': 13}, {'runde': 4, 'card_id': 0}, {'runde': 4, 'card_id': 8}, {'runde': 4, 'card_id': 3}]

# %%
from collections import Counter
card_counts = Counter(
    card_name
    for cards in best_percent["installed_cards"]
    for card_name in cards.values()
)

card_frequency = (
    pd.DataFrame(
        card_counts.items(),
        columns=["Karte", "Anzahl_in_Top_1Prozent"]
    )
    .sort_values("Anzahl_in_Top_1Prozent", ascending=False)
    .reset_index(drop=True)
)

card_frequency["Anteil_Top_100"] = (
    card_frequency["Anzahl_in_Top_1Prozent"] / len(best_percent)
)

card_frequency.head(20)
# Out:
#                                    Karte  Anzahl_in_Top_1Prozent  \
# 0        Passivhaussanierung  ökologisch                     167
# 1                  Tausch der Verglasung                     152
# 2              Dezentrale Lüftungsgeräte                     150
# 3              Mechanische Abluftanlagen                     129
# 4     Ambitionierte Sanierung ökologisch                     112
# 5                 Radiatoren mit Lüftern                     101
# 6              Niedertemperatur Radiator                      91
# 7                  Grosse Dach-PV-Anlage                      86
# 8                            Wandheizung                      80
# 9   Fenstertausch: Passivhaus ökologisch                      78
# 10                Grundwasser-Wärmepumpe                      76
# 11                            Dachgärten                      73
# 12                      Fussbodenheizung                      72
# 13               Zentrale Luftwärmepumpe                      71
# 14               Fenstertausch: Holz-Alu                      69
# 15             Dezentrale Luftwärmepumpe                      69
# 16                 Kleine Dach-PV-Anlage                      60
# 17               Mittlere Dach-PV-Anlage                      59
# 18                   Abwasserwärmepumpen                      56
# 19                         Deckenheizung                      56
#
#     Anteil_Top_100
# 0         0.387471
# 1         0.352668
# 2         0.348028
# 3         0.299304
# 4         0.259861
# 5         0.234339
# 6         0.211137
# 7         0.199536
# 8         0.185615
# 9         0.180974
# 10        0.176334
# 11        0.169374
# 12        0.167053
# 13        0.164733
# 14        0.160093
# 15        0.160093
# 16        0.139211
# 17        0.136891
# 18        0.129930
# 19        0.129930

# %%
id_to_name = cards.set_index("id")["Name"].to_dict()

def extract_installed_cards(played_cards_log):
    return [
        id_to_name.get(entry["card_id"], f"Unknown card ID {entry['card_id']}")
        for entry in played_cards_log
    ]

best_percent["all_installed_cards"] = (
    best_percent["played_cards_log"].apply(extract_installed_cards)
)

best_percent[
    ["game_id", "sp", "all_installed_cards"]
].head(20)
# Out:
#         game_id  sp  \
# 172548    64306 -70
# 203747    75960 -68
# 111535    41639 -58
# 264564    98558 -58
# 169934    63319 -57
# 246446    91871 -57
# 8029       2971 -56
# 147085    54803 -56
# 244256    91038 -56
# 61814     23074 -55
# 153637    57240 -55
# 184409    68701 -55
# 92019     34366 -52
# 131299    48961 -52
# 50700     18907 -51
# 136151    50788 -51
# 7130       2640 -50
# 31642     11738 -50
# 39739     14769 -50
# 177921    66289 -50
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                          all_installed_cards
# 172548                                                                                                                                                                                           [Grosse Dach-PV-Anlage, E-Herd, Mechanische Abluftanlagen, Balkonkraftwerk, Barrierefreier Zugang, Flexibles Lastmanagement, LED Beleuchtung, Passivhaussanierung  ökologisch, Fussbodenheizung, Fenstertausch: Passivhaus ökologisch, Abwasserwärmepumpen]
# 203747                                                                                                                                                              [Grosse Dach-PV-Anlage, E-Herd, Fenstertausch: Holz-Alu, E-Car Lade-Infrastruktur, Barrierefreier Zugang, Fassadenbegrünung , Radiatoren mit Lüftern, Dezentrale Lüftungsgeräte, Passivhaussanierung  ökologisch, Grundwasser-Wärmepumpe, Thermische Flexibilität, Kleiner Heimspeicher]
# 111535                                                                                                                                                                                                                                                                                                           [Flexibles Lastmanagement, Fassadenintegrierte PV, E-Herd, Grosser Batteriespeicher, Intensive Dachbegrünung, Deckenheizung, Balkon-Einbau]
# 264564                                                                                                                       [Balkonkraftwerk, Mittlere Dach-PV-Anlage, E-Herd, E-Car Lade-Infrastruktur, Fassadenintegrierte PV, Mechanische Abluftanlagen, Ambitionierte Sanierung ökologisch, Balkon-Einbau, Grundwasser-Wärmepumpe, Intensive Dachbegrünung, Radiatoren mit Lüftern, Tausch der Verglasung, Kleiner Heimspeicher, Barrierefreier Zugang]
# 169934                                                                                                                                                                                                                                                                   [Radiatoren mit Lüftern, Fenstertausch: Holz-Alu, E-Herd, Flexibles Lastmanagement, Mechanische Abluftanlagen, Dachgärten, Fassadenintegrierte PV, Passivhaussanierung  ökologisch]
# 246446                   [Niedertemperatur Radiator, Dachgärten, Kleiner Heimspeicher, E-Herd, Tausch der Verglasung, Mechanische Abluftanlagen, Flexibles Lastmanagement, LED Beleuchtung, Passivhaussanierung  ökologisch, Grundwasser-Wärmepumpe, Außenliegender Sonnenschutz, Thermische Flexibilität, Balkon-Einbau, Fassadenbegrünung , E-Car Lade-Infrastruktur, Wärmerückgewinnung des Duschwassers, Bi-Direktionelles Laden, Barrierefreier Zugang]
# 8029                                                                                                                                                                                                                                                             [Dachgärten, Flexibles Lastmanagement, Intensive Dachbegrünung, Deckenheizung, E-Herd, Außenliegender Sonnenschutz, Fassadenintegrierte PV, Abwasserwärmepumpen, Dezentrale Lüftungsgeräte]
# 147085                                                                                                                                                                                              [PV-Pergola, Balkonkraftwerk, Flexibles Lastmanagement, E-Herd, Fassadenintegrierte PV, Intensive Dachbegrünung, Mechanische Abluftanlagen, Außenliegender Sonnenschutz, Fenstertausch: Passivhaus ökologisch, Zentrale Luftwärmepumpe, LED Beleuchtung]
# 244256                                                                                                                                                                 [PV-Pergola, Niedertemperatur Radiator, E-Herd, Lift-Einbau, Tausch der Verglasung, Intensive Dachbegrünung, Barrierefreier Zugang, Dezentrale Lüftungsgeräte, LED Beleuchtung, Kleiner Heimspeicher, Abwasserwärmepumpen, Flexibles Lastmanagement, Passivhaussanierung  ökologisch]
# 31642                                                                                                                               [E-Herd, Fassadenintegrierte PV, LED Beleuchtung, Tausch der Verglasung, Kleiner Heimspeicher, Dezentrale Lüftungsgeräte, Thermische Solaranlage, Radiatoren mit Lüftern, Intensive Dachbegrünung, Dezentrale Luftwärmepumpe, Thermische Flexibilität, Barrierefreier Zugang, Balkonkraftwerk, E-Car Lade-Infrastruktur]
# 39739                                                                                                                                                                                                                                                                          [Flexibles Lastmanagement, Fussbodenheizung, E-Herd, Dezentrale Lüftungsgeräte, Tausch der Verglasung, Dachgärten, Grosser Batteriespeicher, Passivhaussanierung  ökologisch]
# 177921                                                                                                                                                                            [Fassadenintegrierte PV, Niedertemperatur Radiator, E-Herd, Außenliegender Sonnenschutz, Mittlere Dach-PV-Anlage, Balkon-Einbau, Intensive Dachbegrünung, Mechanische Abluftanlagen, E-Car Lade-Infrastruktur, Balkonkraftwerk, Grosser Batteriespeicher, LED Beleuchtung]

# %% [markdown]
# # Häufigkeit aller installierten Karten

# %%
all_card_counts = Counter(
    card
    for cards in best_percent["all_installed_cards"]
    for card in cards
)

top_cards = (
    pd.DataFrame(
        all_card_counts.items(),
        columns=["Karte", "Anzahl"]
    )
    .sort_values("Anzahl", ascending=False)
    .reset_index(drop=True)
)

top_cards.head(20)
# Out:
#                                   Karte  Anzahl
# 0                                E-Herd     431
# 1               Intensive Dachbegrünung     276
# 2                 Barrierefreier Zugang     252
# 3                       LED Beleuchtung     251
# 4           Außenliegender Sonnenschutz     233
# 5                       Balkonkraftwerk     220
# 6              Flexibles Lastmanagement     219
# 7                         Balkon-Einbau     204
# 8                  Kleiner Heimspeicher     186
# 9       Passivhaussanierung  ökologisch     167
# 10             E-Car Lade-Infrastruktur     166
# 11               Fassadenintegrierte PV     159
# 12                Tausch der Verglasung     152
# 13            Dezentrale Lüftungsgeräte     150
# 14            Mechanische Abluftanlagen     129
# 15             Grosser Batteriespeicher     129
# 16                   Fassadenbegrünung      127
# 17  Wärmerückgewinnung des Duschwassers     119
# 18                          Lift-Einbau     115
# 19           Effiziente Haushaltsgeräte     115

# %%
# Slot information hinzufügen
import matplotlib.pyplot as plt
from card_colors import slot_colors, default_color
plot_data = (
    top_cards
    .merge(
        cards[["Name", "Slot/Stapel"]],
        left_on="Karte",
        right_on="Name",
        how="left",
    )
    .drop(columns="Name")
    .sort_values("Anzahl")
)

bar_colors = (
    plot_data["Slot/Stapel"]
    .map(slot_colors)
    .fillna(default_color)
)

ax = plot_data.plot.barh(
    x="Karte",
    y="Anzahl",
    color=bar_colors,
    legend=False,
    figsize=(8, 12),
    title="Häufigste Karten in den Top 1% Spielen mit den meisten SP",
)

ax.set_xlabel("Anzahl in den Top-1%-Spielen")
ax.set_ylabel("Karte")

plt.tight_layout()
plt.show()

# %%
best_percent.hist("budget")
df.hist("budget")
# Out:
# array([[<Axes: title={'center': 'budget'}>]], dtype=object)
